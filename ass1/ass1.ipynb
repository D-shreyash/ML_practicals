# %%
import pandas as pd

# %%
dataset = pd.read_csv("/home/shreyash/Desktop/ass1/Dataset.csv")

# %%
dataset
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
dataset.shape #return noo rows and column
# Out:
# (545, 13)

# %%
dataset.head(10) # return firt 10 rows
# Out:
#       price   area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000   7420         4          2        3      yes        no       no
# 1  12250000   8960         4          4        4      yes        no       no
# 2  12250000   9960         3          2        2      yes        no      yes
# 3  12215000   7500         4          2        2      yes        no      yes
# 4  11410000   7420         4          1        2      yes       yes      yes
# 5  10850000   7500         3          3        1      yes        no      yes
# 6  10150000   8580         4          3        4      yes        no       no
# 7  10150000  16200         5          3        2      yes        no       no
# 8   9870000   8100         4          1        2      yes       yes      yes
# 9   9800000   5750         3          2        4      yes       yes       no
#
#   hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
dataset.tail(10) #return last 10 rows
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 535  2100000  3360         2          1        1      yes        no       no
# 536  1960000  3420         5          1        2       no        no       no
# 537  1890000  1700         3          1        2      yes        no       no
# 538  1890000  3649         2          1        1      yes        no       no
# 539  1855000  2990         2          1        1       no        no       no
# 540  1820000  3000         2          1        1      yes        no      yes
# 541  1767150  2400         3          1        1       no        no       no
# 542  1750000  3620         2          1        1      yes        no       no
# 543  1750000  2910         3          1        1       no        no       no
# 544  1750000  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# ...

# %%
dataset.isnull()  #if any value has null or none vale then it get true
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  prefarea  \
# 0       False            False            False    False     False
# ...

# %%
dataset.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# prefarea            0
# furnishingstatus    0
# dtype: int64

# %%
dataset.dtypes  #return data types of each cloumn
# Out:
# price                int64
# area                 int64
# bedrooms             int64
# bathrooms            int64
# stories              int64
# mainroad            object
# guestroom           object
# basement            object
# hotwaterheating     object
# airconditioning     object
# parking              int64
# prefarea            object
# furnishingstatus    object
# dtype: object

# %%
dataset[dataset==0].count() #count number of zeros in each columns
# Out:
# price                 0
# area                  0
# bedrooms              0
# bathrooms             0
# stories               0
# mainroad              0
# guestroom             0
# basement              0
# hotwaterheating       0
# airconditioning       0
# parking             299
# prefarea              0
# furnishingstatus      0
# dtype: int64

# %%
dataset['price'].mean()
# Out:
# 4766729.247706422

# %%
dataset[['area','bedrooms','bathrooms','stories','parking']].mean()
# Out:
# area         5150.541284
# bedrooms        2.965138
# bathrooms       1.286239
# stories         1.805505
# parking         0.693578
# dtype: float64

# %%
copy_dataset=dataset[['area','bedrooms','bathrooms','stories','parking']]

# %%
copy_dataset
# Out:
#      area  bedrooms  bathrooms  stories  parking
# 0    7420         4          2        3        2
# 1    8960         4          4        4        3
# 2    9960         3          2        2        2
# 3    7500         4          2        2        3
# 4    7420         4          1        2        2
# ..    ...       ...        ...      ...      ...
# 540  3000         2          1        1        2
# 541  2400         3          1        1        0
# 542  3620         2          1        1        0
# 543  2910         3          1        1        0
# 544  3850         3          1        2        0
#
# [545 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

# %%
x=dataset[['area','bedrooms','bathrooms','stories','mainroad','guestroom','basement','hotwaterheating','airconditioning','parking','prefarea','furnishingstatus']]

# %%
y=dataset["price"]

# %%
x
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    7420         4          2        3      yes        no       no
# 1    8960         4          4        4      yes        no       no
# 2    9960         3          2        2      yes        no      yes
# 3    7500         4          2        2      yes        no      yes
# 4    7420         4          1        2      yes       yes      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 540  3000         2          1        1      yes        no      yes
# 541  2400         3          1        1       no        no       no
# 542  3620         2          1        1      yes        no       no
# 543  2910         3          1        1       no        no       no
# 544  3850         3          1        2      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 0                no             yes        2      yes        furnished
# ...

# %%
y
# Out:
# 0      13300000
# 1      12250000
# 2      12250000
# 3      12215000
# 4      11410000
#          ...
# 540     1820000
# 541     1767150
# 542     1750000
# 543     1750000
# 544     1750000
# Name: price, Length: 545, dtype: int64

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.25,random_state=42)

# %%
x_train
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 167  4600         2          2        1      yes        no       no
# 368  5640         2          1        1       no        no       no
# 301  3520         3          1        2      yes        no       no
# 527  1836         2          1        1       no        no      yes
# 382  3150         3          1        2      yes        no      yes
# ..    ...       ...        ...      ...      ...       ...      ...
# 71   6000         4          2        4      yes        no       no
# 106  5450         4          2        1      yes        no      yes
# 270  4500         3          2        3      yes        no       no
# 435  4040         2          1        1      yes        no       no
# 102  5500         3          2        4      yes       yes       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 167              no             yes        2       no   semi-furnished
# ...

# %%
x_test
# Out:
#      area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 316  5900         4          2        2       no        no      yes
# 77   6500         3          2        3      yes        no       no
# 360  4040         2          1        1      yes        no       no
# 90   5000         3          1        2      yes        no       no
# 493  3960         3          1        1      yes        no       no
# ..    ...       ...        ...      ...      ...       ...      ...
# 172  8400         3          1        2      yes       yes      yes
# 124  6525         3          2        4      yes        no       no
# 388  3650         3          1        2      yes        no       no
# 521  3635         2          1        1       no        no       no
# 503  4000         3          1        1      yes        no       no
#
#     hotwaterheating airconditioning  parking prefarea furnishingstatus
# 316              no              no        1       no      unfurnished
# ...

# %%
y_train
# Out:
# 167    5285000
# 368    3675000
# 301    4200000
# 527    2275000
# 382    3570000
#         ...
# 71     6755000
# 106    6160000
# 270    4340000
# 435    3290000
# 102    6195000
# Name: price, Length: 408, dtype: int64

# %%
y_test
# Out:
# 316    4060000
# 77     6650000
# 360    3710000
# 90     6440000
# 493    2800000
#         ...
# 172    5250000
# 124    5950000
# 388    3500000
# 521    2408000
# 503    2660000
# Name: price, Length: 137, dtype: int64

# %%
data1=dataset.head(100)

# %%
data1
# Out:
#        price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0   13300000  7420         4          2        3      yes        no       no
# 1   12250000  8960         4          4        4      yes        no       no
# 2   12250000  9960         3          2        2      yes        no      yes
# 3   12215000  7500         4          2        2      yes        no      yes
# 4   11410000  7420         4          1        2      yes       yes      yes
# ..       ...   ...       ...        ...      ...      ...       ...      ...
# 95   6300000  4100         3          2        3      yes        no       no
# 96   6300000  9000         3          1        1      yes        no      yes
# 97   6300000  6400         3          1        1      yes       yes      yes
# 98   6293000  6600         3          2        3      yes        no       no
# 99   6265000  6000         4          1        3      yes       yes      yes
#
# ...

# %%
data2=dataset[["price","area","bedrooms","stories","guestroom"]]

# %%
data2
# Out:
#         price  area  bedrooms  stories guestroom
# 0    13300000  7420         4        3        no
# 1    12250000  8960         4        4        no
# 2    12250000  9960         3        2        no
# 3    12215000  7500         4        2        no
# 4    11410000  7420         4        2       yes
# ..        ...   ...       ...      ...       ...
# 540   1820000  3000         2        1        no
# 541   1767150  2400         3        1        no
# 542   1750000  3620         2        1        no
# 543   1750000  2910         3        1        no
# 544   1750000  3850         3        2        no
#
# [545 rows x 5 columns]

# %%
data3= dataset[["price","area","parking","furnishingstatus","guestroom"]]

# %%
data3
# Out:
#         price  area  parking furnishingstatus guestroom
# 0    13300000  7420        2        furnished        no
# 1    12250000  8960        3        furnished        no
# 2    12250000  9960        2   semi-furnished        no
# 3    12215000  7500        3        furnished        no
# 4    11410000  7420        2        furnished       yes
# ..        ...   ...      ...              ...       ...
# 540   1820000  3000        2      unfurnished        no
# 541   1767150  2400        0   semi-furnished        no
# 542   1750000  3620        0      unfurnished        no
# 543   1750000  2910        0        furnished        no
# 544   1750000  3850        0      unfurnished        no
#
# [545 rows x 5 columns]

# %%
data4=dataset[dataset['furnishingstatus']=='furnished']

# %%
data4
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# 8     9870000  8100         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 509   2590000  3600         2          2        2      yes        no      yes
# 512   2520000  3000         2          1        2      yes        no       no
# 522   2380000  2475         3          1        2      yes        no       no
# 523   2380000  2787         4          2        2      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
#
# ...

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
import warnings

# %%
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
sns.pairplot(dataset)
# Out:
# /home/shreyash/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.pairplot(dataset,hue='parking')
# Out:
# /home/shreyash/.local/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
